# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/life-expectancy.csv')
df
# Out:
#             Entity Code  Year  Period life expectancy at birth
# 0      Afghanistan  AFG  1950                          28.1563
# 1      Afghanistan  AFG  1951                          28.5836
# 2      Afghanistan  AFG  1952                          29.0138
# 3      Afghanistan  AFG  1953                          29.4521
# 4      Afghanistan  AFG  1954                          29.6975
# ...            ...  ...   ...                              ...
# 21560     Zimbabwe  ZWE  2019                          61.0603
# 21561     Zimbabwe  ZWE  2020                          61.5300
# 21562     Zimbabwe  ZWE  2021                          60.1347
# 21563     Zimbabwe  ZWE  2022                          62.3601
# 21564     Zimbabwe  ZWE  2023                          62.7748
#
# [21565 rows x 4 columns]

# %%
df['Entity'].value_counts()
# Out:
# Entity
# Sweden                 273
# United Kingdom         242
# France                 208
# Denmark                190
# Iceland                186
#                       ...
# Armenia                 74
# Zimbabwe                74
# Antigua and Barbuda     74
# Northern Ireland        28
# USSR                     2
# Name: count, Length: 265, dtype: int64

# %%
df['Period life expectancy at birth'].describe()
# Out:
# count    21565.000000
# mean        61.942238
# std         12.925909
# min         10.989100
# 25%         52.703000
# 50%         64.479900
# 75%         71.978900
# max         86.372400
# Name: Period life expectancy at birth, dtype: float64

# %%
df.isna().sum()
# Out:
# Entity                                0
# Code                               1956
# Year                                  0
# Period life expectancy at birth       0
# dtype: int64

# %%
df[df['Code'].isna()]['Entity'].unique()
# Out:
# array(['Africa', 'Americas', 'Asia', 'England and Wales', 'Europe',
#        'High-and-upper-middle-income countries', 'High-income countries',
#        'Land-locked Developing Countries (LLDC)',
#        'Latin America and the Caribbean', 'Least developed countries',
#        'Less developed regions',
#        'Less developed regions, excluding China',
#        'Less developed regions, excluding least developed countries',
#        'Low-and-Lower-middle-income countries',
#        'Low-and-middle-income countries', 'Low-income countries',
#        'Lower-middle-income countries', 'Middle-income countries',
#        'More developed regions', 'No income group available',
#        'Northern America', 'Northern Ireland', 'Oceania', 'Scotland',
#        'Small Island Developing States (SIDS)',
#        'Upper-middle-income countries'], dtype=object)

# %%
df[df['Code'] == 'BRA'].plot(x='Year', y='Period life expectancy at birth', kind='line', title='Expectativa de vida - Brasil')
# Out:
# <Axes: title={'center': 'Expectativa de vida - Brasil'}, xlabel='Year'>

# %%
import matplotlib.pyplot as plt

df_bra = df[df['Code'] == 'BRA']
df_usa = df[df['Code'] == 'USA']
df_chn = df[df['Code'] == 'CHN']

plt.figure(figsize=(9, 5))
plt.plot(df_bra['Year'], df_bra['Period life expectancy at birth'], label='Brasil', color='green')
plt.plot(df_usa['Year'], df_usa['Period life expectancy at birth'], label='Estados Unidos', color='blue')
plt.plot(df_chn['Year'], df_chn['Period life expectancy at birth'], label='China', color='red')

plt.title('Expectativa de vida: Brasil vs Estados Unidos vs China')
plt.xlabel('Ano')
plt.ylabel('Expectativa de vida média')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
